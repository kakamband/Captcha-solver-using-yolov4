# %%
import os
from yolov4_detection import detect

YOLO_DATA_DIR = 'yolo-data'
TEST_DATA_DIR = 'test-treated-4'
filenames = os.listdir(TEST_DATA_DIR)
MIN_CONFIDENCE  = 0.5
NON_MAXIMA_THRESHOLD = 0.3 

for name in filenames:
    detect(os.path.join(TEST_DATA_DIR, name), YOLO_DATA_DIR, MIN_CONFIDENCE, NON_MAXIMA_THRESHOLD)
# Out:
# [INFO] YOLO took 0.181726 seconds
# 0b3b.png
# 0: 0.9821 13 4
# b: 0.9143 40 4
# 3: 0.9996 65 4
# b: 0.9911 87 6
# [INFO] YOLO took 0.181051 seconds
# l42a.png
# l: 0.9564 6 6
# 4: 0.9826 27 4
# 2: 0.9975 49 10
# a: 0.9969 71 16
# [INFO] YOLO took 0.187114 seconds
# j9kg.png
# j: 0.9986 21 3
# 9: 0.9971 43 5
# k: 0.9984 68 9
# 9: 0.9873 89 15
# [INFO] YOLO took 0.189987 seconds
# 3pl4.png
# 3: 0.9967 21 10
# q: 0.8270 44 10
# l: 0.9548 70 12
# 4: 0.9652 90 4
# [INFO] YOLO took 0.198774 seconds
# 262b.png
# 2: 0.9997 21 7
# 6: 0.9993 46 4
# 2: 0.9997 68 9
# b: 0.9894 88 3
# [INFO] YOLO took 0.186121 seconds
# h7v3.png
# h: 0.9632 16 6
# 7: 0.9981 40 4
# v: 0.9753 65 8
# 3: 0.9981 86 5
# [INFO] YOLO took 0.184416 seconds
# 9am0.png
# 9: 0.9952 37 7
# a: 0.9966 59 8
# m: 0.9956 80 10
# 0: 0.9271 102 3
# [INFO] YOLO took 0.184823 seconds
# c5qf.png
# c: 0.9939 28 14
# 5: 0.9964 48 6
# q: 0.9675 76 16
# f: 0.9958 98 2
# [INFO] YOLO took 0.179625 seconds
# x71g.png
# x: 0.9994 19 10
# 7: 0.9993 42 10
# 1: 0.9959 70 6
# g: 0.9979 91 8
# [INFO] YOLO took 0.184779 seconds
# f35o.png
# f: 0.9904 11 5
# 3: 0.9882 39 4
# 5: 0.9990 59 11
# o: 0.9810 75 9
# [INFO] YOLO took 0.186663 seconds
# 0gvf.png
# o: 0.9690 6 8
# g: 0.9687 32 12
# v: 0.9939 50 7
# f: 0.9829 72 10
# [INFO] YOLO took 0.184776 seconds
# tpy1.png
# 5: 0.6003 4 2
# p: 0.9602 33 14
# y: 0.9861 52 15
# 1: 0.9977 79 5
# [INFO] YOLO took 0.178679 seconds
# 124a.png
# 1: 0.9922 10 9
# 2: 0.9994 30 5
# 4: 0.9971 54 5
# a: 0.9952 79 7
# [INFO] YOLO took 0.178727 seconds
# ye72.png
# y: 0.9914 13 16
# e: 0.9864 37 15
# 7: 0.9977 57 5
# 2: 0.9981 81 9
# [INFO] YOLO took 0.183911 seconds
# z2gf.png
# z: 0.9918 26 9
# 2: 0.9994 52 13
# g: 0.9603 68 8
# f: 0.9915 89 4
# [INFO] YOLO took 0.180253 seconds
# ng29.png
# n: 0.9547 22 9
# g: 0.9980 46 10
# 2: 0.9968 67 11
# 9: 0.9932 85 7
# [INFO] YOLO took 0.180077 seconds
# em21.png
# e: 0.9916 42 9
# m: 0.9885 60 12
# 2: 0.9887 88 3
# 1: 0.9945 105 4
# [INFO] YOLO took 0.180772 seconds
# 8ov0.png
# 8: 0.9788 11 10
# o: 0.9876 32 9
# v: 0.9162 59 9
# 0: 0.9993 78 4
# [INFO] YOLO took 0.195491 seconds
# 12y1.png
# 1: 0.9839 33 5
# 2: 0.9986 53 11
# y: 0.9883 74 15
# 1: 0.9934 96 6
# [INFO] YOLO took 0.198455 seconds
# 2lfc.png
# 2: 0.9969 18 10
# l: 0.9833 41 9
# f: 0.9689 65 6
# c: 0.9766 93 10
# [INFO] YOLO took 0.179541 seconds
# x4n6.png
# x: 0.9983 29 10
# 4: 0.9981 55 5
# n: 0.9924 79 17
# 6: 0.9996 106 6
# [INFO] YOLO took 0.181821 seconds
# b5kf.png
# b: 0.6916 32 6
# 5: 0.9985 57 7
# k: 0.9986 79 2
# f: 0.9781 102 5
# [INFO] YOLO took 0.188708 seconds
# h9nw.png
# h: 0.9810 27 11
# 9: 0.9963 56 4
# n: 0.9834 79 16
# w: 0.9965 98 15
# [INFO] YOLO took 0.184577 seconds
# 5nlv.png
# 5: 0.9992 30 6
# n: 0.9818 50 9
# l: 0.9515 71 8
# v: 0.9694 94 9
# [INFO] YOLO took 0.180212 seconds
# oel8.png
# o: 0.9220 10 9
# e: 0.9841 39 12
# l: 0.9872 59 10
# 8: 0.9963 80 4
# [INFO] YOLO took 0.178289 seconds
# 1z7s.png
# 1: 0.9657 38 4
# z: 0.9974 62 16
# 7: 0.9977 81 4
# s: 0.9964 103 11
# [INFO] YOLO took 0.177049 seconds
# is2s.png
# i: 0.9818 46 2
# s: 0.9798 67 13
# 2: 0.9916 88 4
# s: 0.9994 106 16
# [INFO] YOLO took 0.177539 seconds
# kz7j.png
# k: 0.9998 23 7
# z: 0.9927 49 10
# 7: 0.9994 71 9
# j: 0.9989 93 11
